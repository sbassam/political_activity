# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
#df = pd.read_excel('data.xlsx', 'Sheet1', index_col=None, na_values=[''])
df = pd.read_csv('test.csv')
# Out:
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (97,117) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    xml_document_id        ein  \
# 0          1935533  953618401
# 1          1964797  453998754
# 2          1965152  480287347
# 3          1932456  940577270
# 4          1932516  941265639
#
#                                              orgname  \
# 0  Union Employees Vacation Savings and Supplemen...
# 1  UNITED BROTHERHOOD OF CARPENTERS & JOINERS OF ...
# 2                     KANSAS MUNICIPAL UTILITIES INC
# 3              INTL BROTHERHOOD OF ELECT WORKERS 100
# 4                             MARIN VISITORS NETWORK
#
#                                           orgnamecrp  \
# 0  Union Employees Vacation Savings & Supp Dues T...
# 1  United Brotherhood of Carpenters & Joiners of ...
# 2                       Kansas municipal utilities
# 3                                     IBEW Local 100
# 4                             Marin visitors network
#
#                                    ultorg document_link  dba  subsection_code  \
# 0                                     NaN           NaN  NaN              5.0
# 1                                     NaN           NaN  NaN              5.0
# 2                                     NaN           NaN  NaN              4.0
# 3  Intl Brotherhood of Electrical Workers           NaN  NaN              5.0
# 4                                     NaN           NaN  NaN              6.0
#
#                 period_begin                 period_end  ...  filingid  \
# 0  2014-05-01 00:00:00 -0400  2015-04-30 00:00:00 -0400  ...       NaN
# 1  2014-01-01 00:00:00 -0500  2014-12-31 00:00:00 -0500  ...       NaN
# 2  2014-01-01 00:00:00 -0500  2014-12-31 00:00:00 -0500  ...       NaN
# 3  2014-01-01 00:00:00 -0500  2014-12-31 00:00:00 -0500  ...       NaN
# 4  2014-01-01 00:00:00 -0500  2014-12-31 00:00:00 -0500  ...       NaN
#
#   realcode codesource displayyear expoutcands  recipfectot  recipfecattrib  \
# 0    Y4000        NaN      2014.0         0.0          0.0             0.0
# 1    Y4000        NaN      2014.0         0.0          0.0             0.0
# 2    Y4000      ind16      2014.0         0.0          0.0             0.0
# 3    LC150      ind16      2014.0         0.0          0.0             0.0
# 4    Y4000        NaN      2014.0         0.0          0.0             0.0
#
#    schc  schCtot  dupe
# 0   NaN      NaN   NaN
# 1   NaN      NaN   NaN
# 2   NaN      NaN   NaN
# 3   NaN      NaN   NaN
# 4   NaN      NaN   NaN
#
# [5 rows x 118 columns]

# %%
# Let's now choose the important columns:
df = df[['xml_document_id'
,'ein'
,'orgname'
,'tot_volunteers'
,'all_year_employees'
,'tot_rev_current'
,'grants_orgs_us'
,'expenses_total'
,'phone'
,'street'
,'city'
,'state'
,'zip'
,'principal_name'
,'web'
,'period_begin'
,'legal_dom'
,'firm_name'
,'firm_street'
,'firm_city'
,'firm_state'
,'firm_phone'
,'engaged_in_political_act_cbx'
,'officer_business_rel_cbx'
,'family_business_rel_cbx'
,'total_persons_100000'
,'expoutcands'
,'recipfecattrib'
,'source']]

# %%
df['expoutcands'] = pd.to_numeric(df['expoutcands'], errors='coerce');
df['expenses_total'] = pd.to_numeric(df['expenses_total'], errors='coerce');
df['tot_rev_current'] = pd.to_numeric(df['tot_rev_current'], errors='coerce');
df['period_begin'] = pd.to_datetime(df['period_begin'], errors='coerce');

# %%
#df['source'].dtype
df.dtypes
# Out:
# xml_document_id                          int64
# ein                                      int64
# orgname                                 object
# tot_volunteers                         float64
# all_year_employees                     float64
# tot_rev_current                        float64
# grants_orgs_us                         float64
# expenses_total                         float64
# phone                                   object
# street                                  object
# city                                    object
# state                                   object
# zip                                     object
# principal_name                          object
# web                                     object
# period_begin                    datetime64[ns]
# legal_dom                               object
# firm_name                               object
# firm_street                             object
# firm_city                               object
# firm_state                              object
# firm_phone                              object
# engaged_in_political_act_cbx            object
# officer_business_rel_cbx                object
# family_business_rel_cbx                 object
# total_persons_100000                   float64
# expoutcands                            float64
# recipfecattrib                         float64
# source                                  object
# dtype: object

# %%
#df['year'] = df['period_begin'].dt.year
df['period_begin'] = pd.to_datetime(df['period_begin'])
df['year'] = df['period_begin'].dt.year

# %%
df['active'] = 0
df.loc[df['engaged_in_political_act_cbx'] == 'y', 'active'] = 1
df.loc[df['engaged_in_political_act_cbx'] == 'Y', 'active'] = 1
#Test: this should return an empty series:
#df[(df['engaged_in_political_act_cbx'] == 'y') & (df['active'] != 1)]['active']

# %%
df1 = df[(df['year'] == 2014)][['expenses_total','tot_rev_current', 'expoutcands', 'tot_volunteers',
                                'grants_orgs_us', 'all_year_employees',
                                'total_persons_100000', 'recipfecattrib', 'active', 'xml_document_id']]

# %%
df[df['active'] == 1]
# Out:
#        xml_document_id        ein  \
# 11             1932469  940775045
# 19             2005808  201408132
# 30             1932561  941547143
# 42             1936667  370730508
# 57             1961122  130855926
# 58             1999477  940859420
# 72             1961902  221307365
# 82             1998143  370347410
# 84             2011264  430497330
# 97             1961157  132749633
# 105            2000642  361853155
# 109            1937360  590148010
# 111            1928778  726028532
# 113            1933283  953818326
# 129            2001332   60776845
# 159            1912619  230954940
# 174            2006321  237272331
# 176            1964264  410417949
# 180            1967325  880024168
# 194            1961816  205490000
# 201            1967788  951296324
# 210            1924864  530159300
# 220            1963811  363947727
# 224            2018077  135675894
# 264            1967426  911164624
# 273            1963279  311392869
# 288            2008465  251196153
# 293            1963649  351938121
# 295            1967369  910267934
# 313            1964515  426100157
# ...                ...        ...
# 92254           979460  361264200
# 92255           559356  361264200
# 92256           415670  361264200
# 92257           203540  361264200
# 92258          1540229  361264210
# 92259          1190705  361264210
# 92260           865756  361264210
# 92261           339698  361264210
# 92262            91648  361264210
# 92309           208186  636049915
# 92313           645267  636052465
# 92314           475963  636052465
# 92315           249326  636052465
# 92329          1433005  636103495
# 92366          1847981  640204857
# 92367          1460769  640204857
# 92368          1102732  640204857
# 92369           730946  640204857
# 92370           509390  640204857
# 92371           292810  640204857
# 92461          1582350  640334054
# 293                  23.0        4182343.0          6937.0       4286386.0
# 295                  21.0        1224067.0         12555.0       1227972.0
# 313                   0.0        1481768.0        210523.0       1481361.0
# ...                   ...              ...             ...             ...
# 92254                58.0        2872757.0          9380.0       3607106.0
# 92255                43.0        2802288.0         79666.0       3460617.0
# 92256                49.0        3088364.0         53617.0       3524081.0
# 92257                60.0        3697422.0        231016.0       3437413.0
# 92258                 4.0        1618801.0         21863.0       1311688.0
# 92259                 4.0        1468312.0         27900.0       1225682.0
# 92260                 4.0        1199602.0         18785.0       1119757.0
# 92261                 5.0        1030142.0         10995.0       1018523.0
# 92262                 4.0        1369073.0         27655.0       1146988.0
# 92309                23.0        3642428.0             NaN       3287508.0
# 92313                 7.0        3370653.0             NaN       2855486.0
# 92314                 7.0        3255517.0             NaN       2990700.0
# 92315                11.0        3207825.0             NaN       3151181.0
# 92329                 1.0         672434.0             NaN        699067.0
# 92366                 4.0        1295067.0             NaN       1106327.0
# 92367                 4.0        1272845.0             NaN       1153981.0
# 92368                 4.0        1250435.0             NaN       1042899.0
# 92369                 6.0        1430506.0             NaN       1215381.0
# 92370                 0.0        1180729.0             NaN       1050102.0
# 92371                 0.0        1162450.0             NaN       1074819.0
# 92461                 3.0         980294.0             NaN        922863.0
# 92462                 3.0         942463.0             NaN        891778.0
# 92463                 3.0         930420.0             NaN        892644.0
# 92499                27.0       12074778.0       5493104.0      11696593.0
# 92500                25.0       10069290.0       2431814.0       8562336.0
# 92501                27.0        7416697.0       1433534.0       7961566.0
# 92504                58.0        4226790.0             NaN       4700984.0
# 92547                 NaN        2005852.0             NaN       1863780.0
# 92548                 6.0        1811345.0             NaN       1692316.0
# 92549                 6.0        1947160.0         10088.0       1687363.0
#
#               phone                        street  ...      firm_phone  \
# 11     408-225-3030              6150 COTTLE ROAD  ...    925-277-9100
# 19     505-955-8534         460 ST MICHAELS DRIVE  ...    505-603-9690
# 30     925-932-1230          112 BLUE RIDGE DRIVE  ...    925-335-2500
# 42     217-523-2208              241 N Sth Street  ...             NaN
# 57     212-957-8000                709 8TH AVENUE  ...    516-320-7220
# 58     925-314-8600         2610 CROW CANYON ROAD  ...    925-277-9100
# 72     908-686-4550                  3350 HWY 138  ...    908-719-8600
# 82     217-544-3479         3150 WIDE TRACK DRIVE  ...    217-789-0960
# 84              NaN               1611 S BROADWAY  ...    636-549-3060
# 97     718-727-7613               1140 BAY ST A&B  ...    718-979-9700
# 105    708-777-1081             7827 OGDEN AVENUE  ...    708-995-7180
# 109    850-224-7173        516 NORTH ADAMS STREET  ...    850-878-6189
# 111    225-387-2714             660 LAUREL STREET  ...    337-232-3637
# 113    714-258-8330            1405 WARNER AVENUE  ...    714-558-3883
# 129    203-391-9240           150 GARFIELD AVENUE  ...    203-387-7771
# 159    717-238-6715              100 SOUTH STREET  ...    717-843-3804
# 174    212-587-1000              26 Thomas Street  ...    212-564-9451
# 176    651-414-2800           345 RANDOLPH AVENUE  ...    952-841-3950
# 180    702-384-7774         4825 WEST NEVSO DRIVE  ...    702-384-1995
# 194    413-582-0085               150 MAIN STREET  ...    202-331-9880
# 201    909-945-5557                8590 UTICA AVE  ...    949-548-4494
# 210    202-296-4820               1156 15th St NW  ...    703-354-7750
# 220    630-515-0907               6330 BELMONT RD  ...    312-655-0037
# 224    212-604-9552                275 7TH AVENUE  ...    631-273-4778
# 264    866-892-1001      4671 EAST PHILLIPS PLACE  ...    303-733-3796
# 273    614-431-0616       73 E WILSON BRIDGE ROAD  ...    614-457-4888
# 288    814-548-1429           2225 HIGH TECH ROAD  ...    717-761-7171
# 293    765-683-9127               2041 N BROADWAY  ...    312-368-0500
# 295    509-326-2182      1616 N Washington Street  ...    509-747-2158
# 313    202-712-9033              1444 I STREET NW  ...    847-956-1040
# ...             ...                           ...  ...             ...
# 92254  708-449-9000            4415 WEST HARRISON  ...    312-920-9400
# 92255  708-449-9000            4415 WEST HARRISON  ...    312-920-9400
# 92256  708-449-9000            4415 WEST HARRISON  ...    312-920-9400
# 92257  708-449-9000            4415 WEST HARRISON  ...    312-920-9400
# 92258  630-761-1829             1829 SUNCAST LANE  ...    312-655-0037
# 92259  630-761-1829             1829 SUNCAST LANE  ...    312-655-0037
# 92260  630-761-1829             1829 SUNCAST LANE  ...    312-655-0037
# 92261  630-761-1829             1829 SUNCAST LANE  ...    312-655-0037
# 92262  630-761-1829             1829 SUNCAST LANE  ...    312-655-0037
# 92309  205-451-1400              P. O. Box 102066  ...    205-979-6161
# 92313  334-271-6214          4156 CARMICHAEL ROAD  ...    334-271-6678
# 92314  334-271-6214          4156 CARMICHAEL ROAD  ...    334-271-6678
# 92315  334-271-6214          4156 CARMICHAEL ROAD  ...    334-271-6678
# 92329  205-323-1237        2626 12TH AVENUE NORTH  ...    205-802-7212
# 92366  601-939-9909           124 RIVERVIEW DRIVE  ...    601-499-2400
# 92367  601-939-9909           124 RIVERVIEW DRIVE  ...    601-499-2400
# 92368  601-939-9909           124 RIVERVIEW DRIVE  ...    601-499-2400
# 92369  601-939-9909           124 RIVERVIEW DRIVE  ...    601-499-2400
# 92370  601-939-9909           124 RIVERVIEW DRIVE  ...    601-499-2400
# 92371  601-939-9909           124 RIVERVIEW DRIVE  ...    601-957-5050
# 92461  601-981-4552            1400 LAKEOVER ROAD  ...    601-969-7440
# 92462  601-981-4552            1400 LAKEOVER ROAD  ...    601-969-7440
# 92463  601-981-4552                   PO BOX 9575  ...    601-969-7440
# 92499  601-368-3208          POST OFFICE BOX 1909  ...    601-499-2400
# 92500  601-368-3208          POST OFFICE BOX 1909  ...    601-499-2400
# 92501  601-368-3208          POST OFFICE BOX 1909  ...    601-499-2400
# 92504  601-368-3208          POST OFFICE BOX 1909  ...    601-957-5050
# 92547  601-956-3472  1076 highland Colony Parkway  ...    601-981-7571
# 92548  601-956-3472  1076 Highland Colony Parkway  ...    601-981-7571
# 92549  601-956-3472  1076 Highland Colony Parkway  ...    601-981-7571
#
#       engaged_in_political_act_cbx officer_business_rel_cbx  \
# 11                               Y                        N
# 19                               Y                        N
# 30                               Y                        N
# 42                               Y                        N
# 57                               Y                        N
# 58                               Y                        N
# 72                               Y                        N
# 82                               Y                        N
# 84                               Y                        N
# 97                               Y                        N
# 105                              Y                        N
# 109                              Y                        N
# 111                              Y                        N
# 113                              Y                        N
# 129                              Y                        N
# 159                              Y                        N
# 174                              Y                        N
# 176                              Y                        N
# 180                              Y                        N
# 194                              Y                        N
# 201                              Y                        N
# 210                              Y                        N
# 220                              Y                        N
# 224                              Y                        N
# 264                              Y                        N
# 273                              Y                        N
# 288                              Y                        N
# 293                              Y                        N
# 295                              Y                        N
# 313                              Y                        N
# ...                            ...                      ...
# 92254                            Y                        N
# 92255                            Y                        N
# 92256                            Y                        N
# 92257                            Y                        N
# 92258                            Y                        N
# 92259                            Y                        N
# 92260                            Y                        N
# 92261                            Y                        N
# 92262                            Y                        N
# 92309                            Y                        N
# 92313                            Y                        N
# 92314                            Y                        N
# 92315                            Y                        N
# 92329                            Y                        N
# 92366                            Y                        N
# 92367                            Y                        N
# 92368                            Y                        N
# 92369                            Y                        N
# 92370                            Y                        N
# 92371                            Y                        N
# 92461                            Y                        N
# 92462                            Y                        N
# 92463                            Y                        N
# 92499                            Y                        N
# 92500                            Y                        N
# 92501                            Y                        N
# 92504                            Y                        N
# 92547                            Y                        N
# 92548                            Y                        N
# 92549                            Y                        N
#
#       family_business_rel_cbx total_persons_100000 expoutcands recipfecattrib  \
# 11                          N                  5.0         0.0            0.0
# 19                          N                  0.0         0.0            0.0
# 30                          N                  0.0         0.0            0.0
# 42                          N                  1.0         0.0            0.0
# 57                          N                 16.0         0.0            0.0
# 58                          Y                 26.0         0.0            0.0
# 72                          N                  1.0         0.0            0.0
# 82                          N                  3.0         0.0            0.0
# 84                          N                  1.0         0.0            0.0
# 97                          N                  0.0         0.0            0.0
# 105                         Y                  0.0         0.0            0.0
# 109                         N                  6.0         0.0            0.0
# 111                         N                  NaN         0.0            0.0
# 113                         N                  0.0         0.0            0.0
# 129                         N                  6.0         0.0            0.0
# 159                         N                  7.0         0.0            0.0
# 174                         N                  0.0         0.0            0.0
# 176                         N                  6.0         0.0            0.0
# 180                         N                  2.0         0.0            0.0
# 194                         N                  0.0         0.0            0.0
# 201                         N                  2.0         0.0            0.0
# 210                         N                  2.0         0.0            0.0
# 220                         N                 13.0         0.0            0.0
# 224                         N                  3.0         0.0            0.0
# 264                         N                  2.0         0.0            0.0
# 273                         N                  1.0         0.0            0.0
# 288                         N                  NaN         0.0            0.0
# 293                         N                  1.0         0.0            0.0
# 295                         N                  1.0         0.0            0.0
# 313                         N                  0.0         0.0            0.0
# ...                       ...                  ...         ...            ...
# 92254                       N                  7.0         0.0            0.0
# 92255                       N                  7.0         0.0            0.0
# 92256                       N                  6.0         0.0            0.0
# 92257                       N                  8.0         0.0            0.0
# 92258                       N                  2.0         0.0            0.0
# 92259                       N                  1.0         0.0            0.0
# 92260                       N                  1.0         0.0            0.0
# 92261                       N                  2.0         0.0            0.0
# 92262                       N                  3.0         0.0            0.0
# 92309                       N                  1.0         0.0            0.0
# 92313                       N                  2.0         0.0            0.0
# 92314                       N                  2.0         0.0            0.0
# 92315                       N                  3.0         0.0            0.0
# 92329                       N                  0.0         0.0            0.0
# 92366                       N                  1.0         0.0            0.0
# 92367                       N                  NaN         0.0            0.0
# 92368                       N                  1.0         0.0            0.0
# 92369                       N                  1.0         0.0            0.0
# 92370                       N                  1.0         0.0            0.0
# 92371                       N                  1.0         0.0            0.0
# 92461                       N                  1.0         0.0            0.0
# 92462                       N                  1.0         0.0            0.0
# 92463                       N                  1.0         0.0            0.0
# 92499                       N                 10.0         0.0            0.0
# 92500                       N                 10.0         0.0            0.0
# 92501                       N                  3.0         0.0            0.0
# 92504                       N                  8.0         0.0            0.0
# 92547                       N                  1.0         0.0            0.0
# 92548                       N                  1.0         0.0            0.0
# 92549                       N                  1.0         0.0            0.0
#
#       source    year active
# 11        gs  2014.0      1
# 19        gs  2013.0      1
# 30        gs  2014.0      1
# 42        gs  2014.0      1
# 57        gs  2014.0      1
# 58        gs  2014.0      1
# 72        gs  2014.0      1
# 82        gs  2014.0      1
# 84        gs  2014.0      1
# 97        gs  2014.0      1
# 105       gs  2014.0      1
# 109       gs  2014.0      1
# 111       gs  2014.0      1
# 113       gs  2014.0      1
# 129       gs  2014.0      1
# 159       gs  2014.0      1
# 174       gs  2013.0      1
# 176       gs  2014.0      1
# 180       gs  2014.0      1
# 194       gs  2014.0      1
# 201       gs  2014.0      1
# 210       gs  2014.0      1
# 220       gs  2014.0      1
# 224       gs  2014.0      1
# 264       gs  2014.0      1
# 273       gs  2014.0      1
# 288       gs  2014.0      1
# 293       gs  2014.0      1
# 295       gs  2014.0      1
# 313       gs  2014.0      1
# ...      ...     ...    ...
# 92254     gs  2011.0      1
# 92255     gs  2010.0      1
# 92256     gs  2009.0      1
# 92257     gs  2008.0      1
# 92258     gs  2013.0      1
# 92259     gs  2012.0      1
# 92260     gs  2011.0      1
# 92261     gs  2009.0      1
# 92262     gs  2008.0      1
# 92309     gs  2008.0      1
# 92313     gs  2010.0      1
# 92314     gs  2009.0      1
# 92315     gs  2008.0      1
# 92329     gs  2012.0      1
# 92366     gs  2013.0      1
# 92367     gs  2012.0      1
# 92368     gs  2011.0      1
# 92369     gs  2010.0      1
# 92370     gs  2009.0      1
# 92371     gs  2008.0      1
# 92461     gs  2013.0      1
# 92462     gs  2012.0      1
# 92463     gs  2011.0      1
# 92499     gs  2013.0      1
# 92500     gs  2012.0      1
# 92501     gs  2011.0      1
# 92504     gs  2008.0      1
# 92547     gs  2010.0      1
# 92548     gs  2009.0      1
# 92549     gs  2008.0      1
#
# [8629 rows x 31 columns]

# %%
df1.describe()
# Out:
#        expenses_total  tot_rev_current   expoutcands  tot_volunteers  \
# count    1.151100e+04     1.150900e+04  1.151000e+04    8.766000e+03
# mean     8.945394e+06     9.237770e+06  1.342706e+04    6.291282e+02
# std      1.025596e+08     1.021251e+08  5.116819e+05    3.328356e+04
# min      6.300000e+01    -2.365419e+06  0.000000e+00    0.000000e+00
# 25%      7.072840e+05     7.311650e+05  0.000000e+00    0.000000e+00
# 50%      1.159084e+06     1.227516e+06  0.000000e+00    0.000000e+00
# 75%      2.472931e+06     2.648660e+06  0.000000e+00    4.500000e+01
# max      5.531081e+09     5.318096e+09  3.451484e+07    2.930000e+06
#
#        grants_orgs_us  all_year_employees  total_persons_100000  \
# count    4.445000e+03        11209.000000           9628.000000
# mean     7.122580e+05           26.310822              3.467906
# std      2.186696e+07          110.964843             26.837939
# min      0.000000e+00            0.000000             -1.000000
# 25%      0.000000e+00            2.000000              0.000000
# 50%      4.485000e+03            7.000000              1.000000
# 75%      6.792600e+04           19.000000              2.000000
# max      1.440101e+09         5003.000000           1399.000000
#
#        recipfecattrib        active  xml_document_id
# count         11510.0  11513.000000     1.151300e+04
# mean              0.0      0.099019     2.058206e+06
# std               0.0      0.298700     3.205417e+05
# min               0.0      0.000000     1.768956e+06
# 25%               0.0      0.000000     1.933945e+06
# 50%               0.0      0.000000     2.065660e+06
# 75%               0.0      0.000000     2.140011e+06
# max               0.0      1.000000     9.999985e+06

# %%
df1 = df1.dropna()

# %%
# %matplotlib inline
plt.hist(df["expenses_total"].dropna(), bins = 40, range=[1, 12000000])
plt.show()

# %%
# Define features and the label
# label:
labels = ['active']
# features:
features = ['tot_rev_current', 'expoutcands', 'tot_volunteers', 
           'expenses_total', 'grants_orgs_us', 'all_year_employees', 'total_persons_100000', 'recipfecattrib' ]

# %%
from sklearn.cross_validation import train_test_split
features_train, features_test, labels_train, labels_test = \
train_test_split(df1[features], df1[labels], test_size=0.3, random_state=42)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from operator import itemgetter
#Out of the box Decision Tree
clf = tree.DecisionTreeClassifier(random_state = 19)

# fit:
clf.fit(features_train, labels_train)

# predict:
pred = clf.predict(features_test)

# score:
tree_score = clf.score(features_test, labels_test)
print  'accuracy score for tree: ', tree_score

tree_precision = precision_score(labels_test, pred)
print 'precision for tree: ', tree_precision
tree_recall = recall_score(labels_test, pred)
print 'recall for tree: ', tree_recall
importance = sorted(zip(features,clf.feature_importances_), key=itemgetter(1))
print 'feature importances: ', importance
# Out:
# accuracy score for tree:  0.769328263625
# precision for tree:  0.263565891473
# recall for tree:  0.280991735537
# feature importances:  [('recipfecattrib', 0.0), ('expoutcands', 0.057634348231239509), ('total_persons_100000', 0.073181383578744527), ('tot_volunteers', 0.13038657709470636), ('all_year_employees', 0.13483970753549904), ('grants_orgs_us', 0.17961432885305686), ('tot_rev_current', 0.20551477359795364), ('expenses_total', 0.21882888110880003)]

# %%
# Not terrible overall. I haven't done any feature/algorithm selection or parameter/algorithm tuning. I predict the accuracy is 
# going to go up to 90% with precision and recall of about 60% once I do those. Next, I'll try to derive some insight from orgs'
# names and use it as a feature.

# %%
df1['tot_rev_current'].dtype
# Out:
# dtype('float64')

# %%
#remove outliers
# plot to find out if there are outliers

def draw(df, var_x, var_y):
    """ take two features from a dataframe,
        draws a scatterplot
    """
    data = np.array(df[[var_x, var_y, 'active', 'xml_document_id']])

    for point in data:
        x = point[0]
        y = point[1]
        #plt.scatter( expenses_total, tot_rev_current )
        if point[2] == 1:
                plt.scatter( x, y, color = "r" )
        elif point[2] == 0:
                plt.scatter( x, y, color = "b" )
    plt.xlabel(var_x)
    plt.ylabel(var_y)
    #plt.suptitle("Before Removing the Outlier")
    plt.show()


draw(df1, 'expenses_total', 'tot_rev_current')

# %%
draw(df1, 'tot_volunteers', 'tot_rev_current')

# %%
# check expenses_total outliers
df1.sort_values(['expenses_total','tot_rev_current'], ascending = False ).head()
# Out:
#        expenses_total  tot_rev_current  expoutcands  tot_volunteers  \
# 23180    1.952454e+09     1.745022e+09          0.0            10.0
# 24773    1.903437e+09     1.994810e+09          0.0             0.0
# 11499    1.849795e+09     1.898923e+09          0.0             0.0
# 20972    1.813071e+09     1.780755e+09          0.0             0.0
# 12222    1.760418e+09     1.754279e+09          0.0            99.0
#
#        grants_orgs_us  all_year_employees  total_persons_100000  \
# 23180        384600.0              1416.0                  99.0
# 24773             0.0                 0.0                   0.0
# 11499       1254800.0              1581.0                 279.0
# 20972             0.0                 0.0                   0.0
# 12222        396514.0              1080.0                 137.0
#
#        recipfecattrib  active  xml_document_id
# 23180             0.0       1          2176136
# 24773             0.0       0          2141210
# 11499             0.0       0          2154625
# 20972             0.0       0          2153629
# 12222             0.0       0          2141203

# %%
# the following organizations have exceptionally high total revenue. going to consider them outliers till i consult with Robert.
# xml_document_id, orgname, tot_rev_current
# 2103881, Health Insurance Plan of Greater New York, 5,187,437,630
# 2132202, DELTA DENTAL OF CALIFORNIA, 5,318,095,903
df1 = df1.loc[df1['xml_document_id'] != 2103881]
df1 = df1.loc[df1['xml_document_id'] != 2132202]

# %%
# Did that change the performance?
#Out of the box Decision Tree
clf = tree.DecisionTreeClassifier(random_state = 19)

# fit:
clf.fit(features_train, labels_train)

# predict:
pred = clf.predict(features_test)

# score:
tree_score = clf.score(features_test, labels_test)
print  'accuracy score for tree: ', tree_score

tree_precision = precision_score(labels_test, pred)
print 'precision for tree: ', tree_precision
tree_recall = recall_score(labels_test, pred)
print 'recall for tree: ', tree_recall
importance = sorted(zip(features,clf.feature_importances_), key=itemgetter(1))
print 'feature importances: ', importance
# Out:
# accuracy score for tree:  0.767766497462
# precision for tree:  0.237288135593
# recall for tree:  0.231404958678
# feature importances:  [('recipfecattrib', 0.0), ('expoutcands', 0.04539668823131033), ('total_persons_100000', 0.094014643247647481), ('tot_volunteers', 0.15127919841737109), ('expenses_total', 0.16327209397763939), ('tot_rev_current', 0.16492416234117319), ('all_year_employees', 0.17296594588175504), ('grants_orgs_us', 0.20814726790310342)]
