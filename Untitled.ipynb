# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
#df = pd.read_excel('data.xlsx', 'Sheet1', index_col=None, na_values=[''])
df = pd.read_csv('data.csv')
# Out:
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (15,16,17,18,19,60,61,62,75,76,77,78,117,118,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    xml_document_id        ein  \
# 0          1935533  953618401
# 1          1964797  453998754
# 2          1965152  480287347
# 3          1932456  940577270
# 4          1932516  941265639
#
#                                              orgname  \
# 0  Union Employees Vacation Savings and Supplemen...
# 1  UNITED BROTHERHOOD OF CARPENTERS & JOINERS OF ...
# 2                     KANSAS MUNICIPAL UTILITIES INC
# 3              INTL BROTHERHOOD OF ELECT WORKERS 100
# 4                             MARIN VISITORS NETWORK
#
#                                           orgnamecrp  \
# 0  Union Employees Vacation Savings & Supp Dues T...
# 1  United Brotherhood of Carpenters & Joiners of ...
# 2                       Kansas municipal utilities
# 3                                     IBEW Local 100
# 4                             Marin visitors network
#
#                                    ultorg document_link  dba subsection_code  \
# 0                                     NaN           NaN  NaN               5
# 1                                     NaN           NaN  NaN               5
# 2                                     NaN           NaN  NaN               4
# 3  Intl Brotherhood of Electrical Workers           NaN  NaN               5
# 4                                     NaN           NaN  NaN               6
#
#     period_begin       period_end     ...      schc schCtot dupe Unnamed: 118  \
# 0  5/1/2014 0:00   4/30/2015 0:00     ...       NaN     NaN  NaN          NaN
# 1  1/1/2014 0:00  12/31/2014 0:00     ...       NaN     NaN  NaN          NaN
# 2  1/1/2014 0:00  12/31/2014 0:00     ...       NaN     NaN  NaN          NaN
# 3  1/1/2014 0:00  12/31/2014 0:00     ...       NaN     NaN  NaN          NaN
# 4  1/1/2014 0:00  12/31/2014 0:00     ...       NaN     NaN  NaN          NaN
#
#   Unnamed: 119 Unnamed: 120 Unnamed: 121 Unnamed: 122 Unnamed: 123  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 124
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 125 columns]

# %%
df.describe()
# Out:
#        xml_document_id           ein  total_comp_related_org  \
# count     9.263900e+04  9.263900e+04            6.429100e+04
# mean      1.165503e+06  4.942107e+08            6.979547e+05
# std       9.074863e+05  2.693868e+08            9.417587e+06
# min       4.300000e+01  1.002154e+07           -2.734540e+06
# 25%       6.219810e+05  2.621365e+08            0.000000e+00
# 50%       1.112822e+06  4.544328e+08            0.000000e+00
# 75%       1.628670e+06  7.305229e+08            3.039860e+05
# max       9.999999e+06  9.960206e+08            1.005698e+09
#
#        total_comp_other  total_persons_100000  QUALIFIED_RECEIVABLE_EOY  \
# count      7.226400e+04          7.592500e+04              2.379200e+04
# mean       3.203196e+05          1.059979e+05              2.104606e+05
# std        2.966145e+06          8.693828e+05              4.521374e+06
# min       -4.299040e+05         -5.583000e+04             -2.800800e+05
# 25%        0.000000e+00          0.000000e+00              0.000000e+00
# 50%        2.316700e+04          1.000000e+00              0.000000e+00
# 75%        1.643425e+05          6.000000e+00              6.091325e+04
# max        5.413020e+08          6.369044e+07              5.079150e+08
#
#        DISQUALIFIED_RECEIVABLE_BOY  DISQUALIFIED_RECEIVABLE_EOY  \
# count                 1.103000e+04                 1.476300e+04
# mean                  2.616639e+05                 6.884290e+04
# std                   7.147058e+06                 2.953452e+06
# min                  -2.800800e+05                -5.700000e+01
# 25%                   0.000000e+00                 0.000000e+00
# 50%                   5.000000e+02                 0.000000e+00
# 75%                   6.093925e+04                 0.000000e+00
# max                   5.079150e+08                 3.541840e+08
#
#        LOANS_RECEIVABLE_BOY  LOANS_RECEIVABLE_EOY      ...       \
# count          1.107400e+04          1.843500e+04      ...
# mean           1.018576e+07          7.305789e+06      ...
# std            4.071604e+08          3.495274e+08      ...
# min           -1.304130e+05         -8.159800e+04      ...
# 25%            0.000000e+00          0.000000e+00      ...
# 50%            0.000000e+00          0.000000e+00      ...
# 75%            1.070072e+05          1.500000e+04      ...
# max            2.021667e+10          2.038636e+10      ...
#
#        INTANG_ASSETS_EOY  OTHER_ASSETS_BOY  OTHER_ASSETS_EOY  \
# count       1.635400e+04      3.337100e+04      4.243100e+04
# mean        4.302886e+05      1.750898e+06      2.014259e+06
# std         1.636642e+07      4.788172e+07      6.923248e+07
# min        -1.712230e+05     -9.898286e+06     -9.898286e+06
# 25%         0.000000e+00      8.195000e+02      2.000000e+02
# 50%         0.000000e+00      1.255400e+04      9.597000e+03
# 75%         0.000000e+00      1.487835e+05      1.246645e+05
# max         1.300273e+09      8.027525e+09      7.970343e+09
#
#        ASSETS_TOTAL_BOY  ASSETS_TOTAL_EOY  NET_ASSET_CHANGE  Unnamed: 121  \
# count      7.209200e+04      8.139300e+04      5.024500e+04     51.000000
# mean       1.264727e+07      1.368991e+07      5.937409e+06    157.764706
# std        2.259215e+08      2.468091e+08      1.607271e+08    546.171387
# min       -2.323673e+06     -2.857217e+06     -4.254592e+08      0.000000
# 25%        2.448595e+05      3.816690e+05      0.000000e+00      0.000000
# 50%        9.766750e+05      1.182252e+06      2.038760e+05      0.000000
# 75%        3.167762e+06      3.537458e+06      1.504072e+06      0.000000
# max        2.201516e+10      2.217907e+10      2.012872e+10   2013.000000
#
#        Unnamed: 122  Unnamed: 123  Unnamed: 124
# count          14.0           7.0           4.0
# mean            0.0           0.0           0.0
# std             0.0           0.0           0.0
# min             0.0           0.0           0.0
# 25%             0.0           0.0           0.0
# 50%             0.0           0.0           0.0
# 75%             0.0           0.0           0.0
# max             0.0           0.0           0.0
#
# [8 rows x 23 columns]

# %%
df['expenses_total'] = pd.to_numeric(df['expenses_total'], errors='coerce')

# %%
df["expenses_total"].describe()
df["expenses_total"].dtype

# %%
plt.hist(df["expenses_total"].dropna(), bins = 100, range=[1, 12000000])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2bad6724c4b7> in <module>()
# ----> 1 plt.hist(df["expenses_total"].dropna(), bins = 100, range=[1, 12000000])
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
temp = df['expenses_total'].convert_objects(convert_numeric = True)
# Out:
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
plt.hist(df['tot_rev_current'])
# Out:
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: tp_compare didn't return -1 or -2 for exception
#   return umr_minimum(a, axis, None, out, keepdims)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-54e5f862d3ea> in <module>()
# ----> 1 plt.hist(df['tot_rev_current'])
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, data, **kwargs)
#    2956                       histtype=histtype, align=align, orientation=orientation,
#    2957                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2958                       stacked=stacked, data=data, **kwargs)
#    2959     finally:
#    2960         ax.hold(washold)
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
#    1810                                   RuntimeWarning, stacklevel=2)
# -> 1811             return func(ax, *args, **kwargs)
#    1812         pre_doc = inner.__doc__
#    1813         if pre_doc is None:
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5994             for xi in x:
#    5995                 if len(xi) > 0:
# -> 5996                     xmin = min(xmin, xi.min())
#    5997                     xmax = max(xmax, xi.max())
#    5998             bin_range = (xmin, xmax)
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\core\_methods.pyc in _amin(a, axis, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
# ---> 29     return umr_minimum(a, axis, None, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: can't compare datetime.datetime to int

# %%
df2 = df['tot_rev_current'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-2f5353358c90> in <module>()
# ----> 1 df2 = df['tot_rev_current'].astype(float)
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\generic.pyc in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2945
#    2946         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2947                                 raise_on_error=raise_on_error, **kwargs)
#    2948         return self._constructor(mgr).__finalize__(self)
#    2949
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in astype(self, dtype, **kwargs)
#    2871
#    2872     def astype(self, dtype, **kwargs):
# -> 2873         return self.apply('astype', dtype=dtype, **kwargs)
#    2874
#    2875     def convert(self, **kwargs):
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2830
#    2831             kwargs['mgr'] = self
# -> 2832             applied = getattr(b, f)(**kwargs)
#    2833             result_blocks = _extend_blocks(applied, result_blocks)
#    2834
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in astype(self, dtype, copy, raise_on_error, values, **kwargs)
#     420                **kwargs):
#     421         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 422                             values=values, **kwargs)
#     423
#     424     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in _astype(self, dtype, copy, raise_on_error, values, klass, mgr, **kwargs)
#     463
#     464                 # _astype_nansafe works fine with 1-d only
# --> 465                 values = com._astype_nansafe(values.ravel(), dtype, copy=True)
#     466                 values = values.reshape(self.shape)
#     467
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\common.pyc in _astype_nansafe(arr, dtype, copy)
#    2629
#    2630     if copy:
# -> 2631         return arr.astype(dtype)
#    2632     return arr.view(dtype)
#    2633
#
# ValueError: could not convert string to float: Y

# %%
df.dtypes
# Out:
# xml_document_id                       int64
# ein                                   int64
# orgname                              object
# orgnamecrp                           object
# ultorg                               object
# document_link                        object
# dba                                  object
# subsection_code                      object
# period_begin                         object
# period_end                           object
# change_addr_cbx                      object
# change_name_cbx                      object
# init_ret_cbx                         object
# final_ret_cbx                        object
# app_pend_cbx                         object
# tot_volunteers                       object
# all_year_employees                   object
# tot_rev_current                      object
# grants_orgs_us                       object
# expenses_total                       object
# phone                                object
# street                               object
# suite                                object
# city                                 object
# state                                object
# country                              object
# zip                                  object
# principal_name                       object
# firstname                            object
# middlename                           object
#                                      ...
# FUNDRAISING_PHONE_CBX                object
# FUNDRAISING_PERSON_CBX               object
# FUNDRAISING_NON_GOV_GRANTS_CBX       object
# FUNDRAISING_GOV_GRANTS_CBX           object
# FUNDRAISING_SPECIAL_EVENTS_CBX       object
# FUNDRAISING_PROF_CBX                 object
# FUNDRAISING_TOTAL_GROSS_RECEIPTS     object
# TOTAL_PAID_TO_FUNDRAISER             object
# FUNDRAISING_TOTAL_PAID_ORG           object
# source                               object
# mark                                 object
# orgid                                object
# cmteid                               object
# filingid                             object
# realcode                             object
# codesource                           object
# displayyear                          object
# expoutcands                          object
# recipfectot                          object
# recipfecattrib                       object
# schc                                 object
# schCtot                              object
# dupe                                 object
# Unnamed: 118                         object
# Unnamed: 119                         object
# Unnamed: 120                         object
# Unnamed: 121                        float64
# Unnamed: 122                        float64
# Unnamed: 123                        float64
# Unnamed: 124                        float64
# dtype: object

# %%
pd.to_numeric(df['expenses_total'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-daf954fa5029> in <module>()
# ----> 1 pd.to_numeric(df['expenses_total'])
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\tools\util.pyc in to_numeric(arg, errors)
#      96         conv = lib.maybe_convert_numeric(arg,
#      97                                          set(),
# ---> 98                                          coerce_numeric=coerce_numeric)
#      99     except:
#     100         if errors == 'raise':
#
# pandas\src\inference.pyx in pandas.lib.maybe_convert_numeric (pandas\lib.c:53932)()
#
# pandas\src\inference.pyx in pandas.lib.maybe_convert_numeric (pandas\lib.c:53719)()
#
# ValueError: Unable to parse string

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-c8f4d45f8147> in <module>()
# ----> 1 df['expenses_total'].astype(int)
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\generic.pyc in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2945
#    2946         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2947                                 raise_on_error=raise_on_error, **kwargs)
#    2948         return self._constructor(mgr).__finalize__(self)
#    2949
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in astype(self, dtype, **kwargs)
#    2871
#    2872     def astype(self, dtype, **kwargs):
# -> 2873         return self.apply('astype', dtype=dtype, **kwargs)
#    2874
#    2875     def convert(self, **kwargs):
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2830
#    2831             kwargs['mgr'] = self
# -> 2832             applied = getattr(b, f)(**kwargs)
#    2833             result_blocks = _extend_blocks(applied, result_blocks)
#    2834
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in astype(self, dtype, copy, raise_on_error, values, **kwargs)
#     420                **kwargs):
#     421         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 422                             values=values, **kwargs)
#     423
#     424     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in _astype(self, dtype, copy, raise_on_error, values, klass, mgr, **kwargs)
#     463
#     464                 # _astype_nansafe works fine with 1-d only
# --> 465                 values = com._astype_nansafe(values.ravel(), dtype, copy=True)
#     466                 values = values.reshape(self.shape)
#     467
#
# C:\Users\sbassam\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\common.pyc in _astype_nansafe(arr, dtype, copy)
#    2626     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#    2627         # work around NumPy brokenness, #1987
# -> 2628         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    2629
#    2630     if copy:
#
# pandas\lib.pyx in pandas.lib.astype_intsafe (pandas\lib.c:16620)()
#
# pandas\src\util.pxd in util.set_value_at (pandas\lib.c:67979)()
#
# ValueError: cannot convert float NaN to integer
